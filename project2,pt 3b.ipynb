# %% [markdown]
# # Part 3B
#  -  **Transform and Load**
#
#   -  Nicholas Giuffrida

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from sqlalchemy.types import *
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import glob

# %%
df = pd.read_csv('Data/B_filtered.csv', low_memory=False)

# %%
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86979 entries, 0 to 86978
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86979 non-null  object
#  1   titleType       86979 non-null  object
#  2   primaryTitle    86979 non-null  object
#  3   originalTitle   86979 non-null  object
#  4   isAdult         86979 non-null  int64
#  5   startYear       86979 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  86979 non-null  int64
#  8   genres          86979 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 6.0+ MB

# %%
df['genres'].value_counts()
# Out:
# Drama                        17085
# Comedy                        7148
# Horror                        4071
# Comedy,Drama                  4000
# Drama,Romance                 2623
#                              ...
# Music,Mystery,Romance            1
# History,Horror,Mystery           1
# Crime,Music,Mystery              1
# Crime,Fantasy,Romance            1
# Biography,Fantasy,Musical        1
# Name: genres, Length: 854, dtype: int64

# %%
## create a col with a list of genres
df['genres_split'] = df['genres'].str.split(',')
df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 86974  tt9914942     movie                             Life Without Sara Amat
# 86975  tt9915872     movie                               The Last White Witch
# 86976  tt9916170     movie                                      The Rehearsal
# 86977  tt9916190     movie                                          Safeguard
# 86978  tt9916362     movie                                              Coven
#
# ...

# %%
# Convert string column into list  of strings
genres_split = df['genres'].str.split(",")
# Explode, and get unique entries
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Biography', 'Mystery', 'Musical', 'Action', 'Adventure', 'Crime',
#        'Thriller', 'Music', 'Animation', 'Family', 'History', 'War',
#        'Sport', 'Western', 'Adult', 'Reality-TV', 'News', 'Talk-Show',
#        'Game-Show'], dtype=object)

# %%
exploded_genres = df.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 86977  tt9916190     movie                                          Safeguard
# 86977  tt9916190     movie                                          Safeguard
# 86977  tt9916190     movie                                          Safeguard
# 86978  tt9916362     movie                                              Coven
# 86978  tt9916362     movie                                              Coven
#
# ...

# %%
# Alphabetize unique genres
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
# Save title genres DataFrame
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head(3)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance

# %%
title_genres
# Out:
#           tconst genres_split
# 0      tt0035423       Comedy
# 0      tt0035423      Fantasy
# 0      tt0035423      Romance
# 1      tt0062336        Drama
# 2      tt0069049        Drama
# ...          ...          ...
# 86977  tt9916190       Action
# 86977  tt9916190    Adventure
# 86977  tt9916190     Thriller
# 86978  tt9916362        Drama
# 86978  tt9916362      History
#
# [162600 rows x 2 columns]

# %%
# Make genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
# Replace Genres split with Genre id
df['genre_id'] = df['genres_split'].replace(genre_map)
df = df.drop(columns='genres_split')
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres                    genre_id
# ...

# %%
genre_look = pd.DataFrame({'genre_name': genre_map.keys(),
                   'genre_id' : genre_map.values()})
genre_look.head(3)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2

# %%
genre_look.dtypes
# Out:
# genre_name    object
# genre_id       int64
# dtype: object

# %%
# Get max string length
max_str_len = genre_look['genre_name'].fillna('').map(len).max()
max_str_len
# Out:
# 10

# %%
with open('/Users/nicholasgiuffrida/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
connection = f"mysql+pymysql://{login['username']}:{(login['password'])}@localhost/movies_db"
engine = create_engine(connection)
conn = engine.connect()

# %%
q = """SHOW tables

"""""
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies_db
# 0              genres
# 1             ratings
# 2        title_basics
# 3        title_genres
# 4           tmdb_data

# %%
df_schema = {
    "genre_id": INTEGER(),
    'genre_name':VARCHAR(11)}

# %%
genre_look.to_sql('genres', conn, dtype=df_schema, index=False, if_exists='replace')
# Out:
# 25

# %%
tg_schema ={
    'tconst': VARCHAR(10),
    'genre_id' : INTEGER()}

# %%
title_genres.to_sql('title_genres', conn, dtype=tg_schema, index=False, if_exists='replace')
# Out:
# 162600

# %%
q = """SHOW tables

"""""
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies_db
# 0              genres
# 1             ratings
# 2        title_basics
# 3        title_genres
# 4           tmdb_data

# %%
# Use glob to get all filepaths that match the pattern (*=wildcard)
tmdb_files = sorted(glob.glob("Data/fin_tmdb_data_*.csv.gz"))
tmdb_files
# Out:
# ['Data/fin_tmdb_data_2001.csv.gz', 'Data/fin_tmdb_data_2002.csv.gz']

# %%
# Use read_csv in a list comprehension and combine with concat to load all files
df = pd.concat([pd.read_csv(f) for f in tmdb_files] )
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %% [markdown]
# ##  RESUBMIT
# -  Please fill in the data for the tmdb data table. Right now, the table is empty.

# %%
q = """SELECT * FROM tmdb_data

"""""
pd.read_sql(q, conn)
# Out:
# Empty DataFrame
# Columns: [imdb_id, revenue, budget, certification]
# Index: []

# %%
td_schema ={
    'imdb_id': VARCHAR(10),
    'revenue' : INTEGER(),
    'budget': INTEGER(),
    'certification':VARCHAR(7)}

# %%
df.to_sql('tmdb_data', conn, dtype=td_schema, index=False, if_exists='replace')
# Out:
# 2645

# %%
q = """SELECT * FROM tmdb_data
LIMIT 5
"""""
pd.read_sql(q, conn)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                              None                  None
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                  None
# 2  tt0114447    0.0                              None                  None
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                  None
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                  None
#
#        budget                                             genres homepage  \
# 0         NaN                                               None     None
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...     None
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...     None
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     None
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...     None
#
# ...

# %%
q = """SELECT * FROM genres
LIMIT 5
"""""
pd.read_sql(q, conn)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
q = """SELECT * FROM title_genres

LIMIT 5
"""""
pd.read_sql(q, conn)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 1  tt0035423      Fantasy
# 2  tt0035423      Romance
# 3  tt0062336        Drama
# 4  tt0069049        Drama

# %% [markdown]
# ## PART 3b finished
# -  Including resubmit
